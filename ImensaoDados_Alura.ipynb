# %% [markdown]
# <a href="https://colab.research.google.com/github/vizidora/ImersaoDados_Alura/blob/main/ImensaoDados_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from collections import Counter
url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
dados = pd.read_csv(url_dados, compression = "zip")
dados.columns = dados.columns.str.replace("-", "")
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados["tratamento"].tail()
# Out:
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, dtype: object

# %% [markdown]
# Resultado dos desafios:
# 1:

# %%
dados["tratamento"].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
len(dados["dose"].value_counts())
# Out:
# 2

# %%
dados["droga"].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 57f5932fb       1
# d75904698       1
# c1292b6d8       1
# a9bc2c549       1
# ef4e67d99       1
# Name: droga, Length: 3289, dtype: int64

# %%
dados.droga.nunique()
# Out:
# 3289

# %% [markdown]
# Desafios
# ### Desafio 01: Investigar por que a classe tratamento é tão desbalanceada.<br>
# 1: A droga "cacb2b860" é a droga de controle.<br>
# ###Desafio 02: Plotar as 5 últimas linhas da tabela<br>
# 2: dados.tail()<br>
# ###Desafio 03: Proporção das classes tratamento.<br>
# 3: round(dados["tratamento"].value_counts(normalize = True), ndigits= 2)<br>
# ###Desafio 04: Quantos tipos de drogas foram investigados.<br>
# Alguns modos de resolver esse desafio:
# 4: len(dados["droga"].value_counts())<br>
# dados.droga.nunique()<br>
# ###Desafio 05: Procurar na documentação o método query (pandas).<br>
# 5: dados.query("tempo > 24")<br>
# ###Desafio 06: Renomear as colunas tirando o hífen.<br>
# Alguns modos de resolver esse desafio:<br>
# nome_coluna = dados.rename(columns={"g-0": "g_0"})<br>
# dados.columns = dados.columns.str.replace("-", "")<br>
# mapa = ("droga" : "composto")<br>
# dados.rename(columns = mapa, inplace = True)<br>
# ###Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)<br>
# def cria_labels_feliz(labels):
#                       return [label.replace("_", " ").capitalize() for label in labels]
# tipos_de_tratamento = dados.tratamento.value_counts()
# labels = cria_labels_feliz(dados.tratamento.unique())
# explode = (0,0.2)
# plt.title("Tipos de tratamento")
# plt.pie(tipos_de_tratamento, labels = labels, shadow = True, explode = explode, autopct= "%1.1f%%")
# plt.show()<br>
# ###Desafio 08: Resumo do que você aprendeu com os dados.

# %%
 pd.crosstab(dados["tratamento"], dados["tratamento"])
# Out:
# tratamento    com_controle  com_droga
# tratamento
# com_controle          1866          0
# com_droga                0      21948

# %%
round(dados["tratamento"].value_counts(normalize = True), ndigits= 2)
# Out:
# com_droga       0.92
# com_controle    0.08
# Name: tratamento, dtype: float64

# %%
dados["tratamento"].value_counts().plot.pie()

# %%
dados["tempo"].value_counts().plot.bar()

# %%
dados.shape
# Out:
# (23814, 877)

# %%
nome_coluna = dados.rename(columns={"g-0": "g0"})

# %%
dados.columns = dados.columns.str.replace("-", "")
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
nome_coluna
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
def cria_labels_feliz(labels):
                      return [label.replace("_", " ").capitalize() for label in labels]
tipos_de_tratamento = dados.tratamento.value_counts()
labels = cria_labels_feliz(dados.tratamento.unique())
explode = (0,0.2)
plt.title("Tipos de tratamento")
plt.pie(tipos_de_tratamento, labels = labels, shadow = True, explode = explode, autopct= "%1.1f%%")
plt.show()

# %%
mapa = {"droga" : "composto"}
dados.rename(columns = mapa, inplace = True)

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
cod_compostos = dados["composto"].value_counts().index[0:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query("composto in @cod_compostos") #@ é necessário quando precisamos acessar uma variável que está em outro bloco de código
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
plt.figure(figsize=(8,6)) #tamanho do grafico
ax = sns.countplot(x = "composto", data = dados.query("composto in @cod_compostos"),  order = cod_compostos) #countplot plota e conta
ax.set_title("Top 5 compostos", fontsize = 18)
plt.xlabel("Composto", fontsize=16)
plt.ylabel('Contagem', fontsize=16)
plt.show()

# %%
len(dados.g0.unique())
# Out:
# 14367

# %%
dados.g0.min()
# Out:
# -5.513

# %%
dados.g0.max()
# Out:
# 10.0

# %%
dados.g0.hist(bins = 100)
plt.show()

# %%
sns.histplot(x = "g0", data = dados)
plt.show()

# %%
dados.describe() #equivale ao str do R, traz as informações de estatistica
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados.loc[:, "g0":].describe() #seleciona linhas e colunas, se não colocar nada no começo significa que a seleção começa do indice 0, se não colocar nada após os : simboliza
                              #que a seleção vai até o final da linha ou da coluna, dependendo de onde estiver posicionado
# Out:
#                  g0            g1  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.470252     -0.301505
# std        1.393399      0.812363  ...      1.834828      1.407918
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.592600     -0.562900
# 50%       -0.008850     -0.046600  ...      0.014000     -0.019500
# 75%        0.525700      0.403075  ...      0.461275      0.438650
# max       10.000000      5.039000  ...      3.111000      3.805000
#
# [8 rows x 872 columns]

# %%
dados.loc[:, "g0":"g711"].describe().T["mean"].hist(bins = 30)

# %%
dados.loc[:, "g0":"g711"].describe().T["min"].hist(bins = 30)

# %%
dados.loc[:, "g0":"g711"].describe().T["max"].hist(bins = 30)

# %%
dados.loc[:, "c0":"c99"].describe().T["mean"].hist(bins = 30)

# %%
sns.boxplot(x="g0", data = dados)
plt.show()

# %%
plt.figure(figsize = (10,8))
ax = sns.boxplot(x = "tratamento", y = "g0", data = dados)
ax.set_title("BoxPlot", fontsize = 18)
plt.xlabel("Tratamento", fontsize=16)
plt.ylabel('G0', fontsize=16)
plt.show()

# %%
pd.crosstab(dados.dose, dados.tempo)
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados.dose, dados.tempo], dados.tratamento)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
round(pd.crosstab([dados.dose, dados.tempo], dados.tratamento, normalize="index"), ndigits=3)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            0.077      0.923
#      48            0.079      0.921
#      72            0.079      0.921
# D2   24            0.078      0.922
#      48            0.078      0.922
#      72            0.079      0.921

# %%
pd.crosstab([dados.dose, dados.tempo], dados.tratamento, normalize="columns")
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
round(pd.crosstab([dados["dose"], dados["tempo"]], dados["tratamento"], values=dados["g0"], aggfunc="mean"), ndigits=3)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -0.252      0.368
#      48           -0.123      0.412
#      72           -0.295      0.286
# D2   24            0.011      0.115
#      48            0.013      0.214
#      72            0.070      0.253

# %%
dados.groupby(["dose", "tempo"])["tratamento"].value_counts(normalize=True)
# Out:
# dose  tempo  tratamento
# D1    24     com_droga       0.922542
#              com_controle    0.077458
#       48     com_droga       0.921222
#              com_controle    0.078778
#       72     com_droga       0.921423
#              com_controle    0.078577
# D2    24     com_droga       0.921513
#              com_controle    0.078487
#       48     com_droga       0.921715
#              com_controle    0.078285
#       72     com_droga       0.921493
#              com_controle    0.078507
# Name: tratamento, dtype: float64

# %%
dados_melt = pd.melt(dados, ['id', 'tempo', 'dose', 'composto', 'tratamento'])
dados_melt.head()
# Out:
#              id  tempo dose   composto tratamento variable   value
# 0  id_000644bb2     24   D1  b68db1d53  com_droga       g0  1.0620
# 1  id_000779bfc     72   D1  df89a8e5a  com_droga       g0  0.0743
# 2  id_000a6266a     48   D1  18bb41b2c  com_droga       g0  0.6280
# 3  id_0015fd391     48   D1  8c7f86626  com_droga       g0 -0.5138
# 4  id_001626bd3     72   D2  7cbed3131  com_droga       g0 -0.3254

# %%
dados[["g0","g3"]]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
dados[["g0","g8"]]
# Out:
#            g0      g8
# 0      1.0620  0.5548
# 1      0.0743 -0.4047
# 2      0.6280  0.0065
# 3     -0.5138 -0.1321
# 4     -0.3254 -0.8789
# ...       ...     ...
# 23809  0.1394 -0.4726
# 23810 -1.3260  0.5112
# 23811  0.3942 -0.0340
# 23812  0.6660  0.4299
# 23813 -0.8598  3.0790
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x="g0", y="g3", data=dados)

# %%
sns.scatterplot(x="g0", y="g8", data=dados)

# %%
sns.lmplot(x="g0", y="g8", data=dados, line_kws={"color": "red"})

# %%
sns.lmplot(x="g0", y="g8", data=dados, line_kws={"color": "red"}, col = "tratamento")

# %%
sns.lmplot(x="g0", y="g8", data=dados, line_kws={"color": "red"}, col = "tratamento", row="tempo")

# %%
dados.loc[:, "g0":"g711"].corr()
# Out:
#             g0        g1        g2  ...      g709      g710      g711
# g0    1.000000  0.086032  0.176188  ... -0.227691  0.426917  0.269032
# g1    0.086032  1.000000 -0.054518  ...  0.023665 -0.070588  0.023646
# g2    0.176188 -0.054518  1.000000  ... -0.083571  0.092079  0.116229
# g3    0.011266 -0.027855  0.042633  ... -0.088272 -0.020720  0.197289
# g4    0.403153  0.193647  0.013968  ... -0.059669  0.188710  0.130505
# ...        ...       ...       ...  ...       ...       ...       ...
# g707  0.011391 -0.002208  0.002540  ... -0.033378 -0.002302 -0.003678
# g708  0.381758  0.001169  0.123948  ... -0.215672  0.197536  0.510416
# g709 -0.227691  0.023665 -0.083571  ...  1.000000 -0.158232 -0.314455
# g710  0.426917 -0.070588  0.092079  ... -0.158232  1.000000  0.095093
# g711  0.269032  0.023646  0.116229  ... -0.314455  0.095093  1.000000
#
# [712 rows x 712 columns]

# %%
corr = dados.loc[:, "g0":"g50"].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:, "c0":"c50"].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Aula 4

# %%
dados_resultados = pd.read_csv("https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true")
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados.acat_inhibitor.unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes("int64").sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa2 = dados_resultados.drop("id", axis=1).sum().sort_values(ascending=False)
contagem_moa2
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop("id", axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados["n_moa"] = dados_resultados.drop("id", axis=1).sum(axis=1)

# %%
dados_resultados["ativo_moa"] = (dados_resultados["n_moa"] !=0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[["id", "n_moa", "ativo_moa"]], on="id")
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query("tratamento == 'com_controle'")["ativo_moa"].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query("tratamento == 'com_droga'")["ativo_moa"].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados.composto.value_counts().index[:5]
composto_principal
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
plt.figure(figsize = (12, 8))
sns.boxplot(data = dados_combinados.query("composto in @composto_principal"), y="g0", x="composto", hue="ativo_moa")

# %%
from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes("float64")
y = dados_combinados["ativo_moa"]
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify = y, random_state = 376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier("most_frequent")
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score (y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados.ativo_moa.value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes("float64")
y = dados_combinados["ativo_moa"]
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify = y, random_state = 376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %%
from sklearn import  tree

fig, ax = plt.subplots(figsize = (15, 10), facecolor = "k")
tree.plot_tree(modelo_arvore,
               ax = ax,
               fontsize = 10,
               rounded = True,
               filled = True,
               feature_names = x_treino.columns,
               class_names = ["Ativado", "Não ativado"])
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes("float64")
y = dados_combinados["ativo_moa"]
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify = y, random_state = 376)

teste=[]
treino=[]
for i in range(1,15):
  modelo_arvore = DecisionTreeClassifier(max_depth = i)
  modelo_arvore.fit(x_treino, y_treino)
  teste.append(modelo_arvore.score(x_teste, y_teste))
  treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6204073063195465,
#  0.6208272097417594,
#  0.6183077892084821,
#  0.6208272097417594,
#  0.6195674994751207,
#  0.6166281755196305,
#  0.6132689481419273,
#  0.6090699139197985,
#  0.5977325215200504,
#  0.5992021834977955,
#  0.5975225698089439]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6605427536612252,
#  0.6707259461445594,
#  0.689570101307018,
#  0.706892026665267,
#  0.7292530575822791,
#  0.7529788462547897,
#  0.7770720697076269,
#  0.7994331006246391]

# %%
sns.lineplot(x=range(1,15), y= teste, label = "teste")
sns.lineplot(x=range(1,15), y= treino, label = "treino")

# %%
pd.get_dummies(dados_combinados.tratamento)
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns = ["tratamento", "dose", "tempo"])
# Out:
#                  id   composto      g0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(["id", "n_moa", "ativo_moa", "composto"], axis=1)
x = pd.get_dummies(x, columns = ["tratamento", "dose", "tempo"])
y = dados_combinados["ativo_moa"]
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2, stratify = y, random_state = 376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6787738820071384
